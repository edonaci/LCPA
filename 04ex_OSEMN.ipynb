# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import scipy as sp
import sklearn as sl
from scipy import stats
from sklearn import datasets
from sklearn import linear_model
import numpy.random as npr

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
import numpy.random as npr

f = open('simple_data.txt', 'w')

i=0

while(i<10):
    f.write(str( npr.randint(1,100))+"\n" )
    i+=1

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
import numpy.random as npr

f=open("data.txt","w")
x=0
matrix=[]
while(x<25):
    aux=npr.randint(1,100)
    matrix.append(aux)
    x+=1

matrix=np.array(matrix)
matrix=matrix.reshape(5,5)

f.write(str(matrix))
# Out:
# 90

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
load_data="data.txt"
csvfile=open("data.csv","w")

with open(load_data, mode='r') as f:
    for line in f:
        csvfile.write(line + ",")

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number

# %%
import numpy as np

load_data="credit_card.dat"
cc=open(load_data,"r")

with open(load_data,mode="r") as file:
    file_content=file.read()
    word_size=6
    j=0
    a=0
    b=word_size
    while a!=len(file_content)//6 :
        
        
        if file_content[a:b-1]=="1010\n":
            print("\n \n")
            a=a+word_size-1
            b=a+word_size
            print("carta di credito numero ",j//19)
            
        if j//19==50:
            break
        #print(file_content[a:b])    
        print( chr( int( file_content[a:b],2 ) ),"\n" )
        
        a=a+word_size
        b=a+word_size
        
        j+=1
# Out:
# 7
#
# 6
#
# 4
#
# 8
#
#
#
# 5
#
# 6
#
# 7
#
# 3
#
#
#
# 3
#
# 7
#
# 7
#
# 5
#
#
#
# 2
#
# 2
#
# 7
#
# 1
#
#
#
#
# carta di credito numero  1
# 3
#
# 2
#
# 5
#
# 7
#
#
#
# 8
#
# 2
#
# 4
#
# 7
#
#
#
# 3
#
# 3
#
# 5
#
# 4
#
#
#
# 2
#
# 2
#
# 6
#
# 6
#
#
#
#
# carta di credito numero  2
# 2
#
# 7
#
# 2
#
# 2
#
#
#
# 0
#
# 0
#
# 0
#
# 1
#
#
#
# 4
#
# 0
#
# 1
#
# 1
#
#
#
# 6
#
# 6
#
# 5
#
# 2
#
#
#
#
# carta di credito numero  3
# 0
#
# 6
#
# 6
#
# 1
#
#
#
# 3
#
# 0
#
# 6
#
# 3
#
#
#
# 3
#
# 7
#
# 4
#
# 2
#
#
#
# 3
#
# 1
#
# 5
#
# 0
#
#
#
#
# carta di credito numero  4
# 0
#
# 4
#
# 3
#
# 2
#
#
#
# 1
#
# 6
#
# 0
#
# 8
#
#
#
# 1
#
# 4
#
# 6
#
# 2
#
#
#
# 4
#
# 7
#
# 4
#
# 2
#
#
#
#
# carta di credito numero  5
# 5
#
# 8
#
# 2
#
# 7
#
#
#
# 2
#
# 0
#
# 2
#
# 7
#
#
#
# 8
#
# 7
#
# 8
#
# 5
#
#
#
# 7
#
# 3
#
# 0
#
# 3
#
#
#
#
# carta di credito numero  6
# 5
#
# 7
#
# 7
#
# 4
#
#
#
# 8
#
# 5
#
# 2
#
# 8
#
#
#
# 2
#
# 0
#
# 8
#
# 7
#
#
#
# 1
#
# 1
#
# 1
#
# 7
#
#
#
#
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import numpy as np
import json
import csv
data = json.load(open('user_data.json'))
AE=[]
for i in range( len(data) ):
    if data[i]['CreditCardType']=='American Express':
        AE.append(data[i])
        
with open('AmericanExpress.csv', 'w', newline='', encoding='utf-8') as csv_file: 
    writer = csv.writer(csv_file, delimiter=';') 
    writer.writerow(AE)

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
import pandas as pd
file_name="https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1"
data=pd.read_csv(file_name)
data

# %matplotlib inline
data.hist("class")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D97C613160>]],
#       dtype=object)

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
import pandas as pd
file_name="https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1"
data=pd.read_csv(file_name)
data
# %matplotlib inline
data.plot.scatter("features_1","features_2",)
data.plot.scatter("features_2","features_3")
data.plot.scatter("features_1","features_3")
data.plot.scatter("features_2","features_1")
data.plot.scatter("features_3","features_1")
data.plot.scatter("features_3","features_2")

# %% [markdown]
# 8. Load the same file of point 6, and convert the file to json with Pandas.

# %%
import pandas as pd 
file_name="https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1"
data=pd.read_csv(file_name)
df=pd.DataFrame(data)
out = df.to_json(orient='records')[1:-1].replace('},{', '} {')
with open('mushrooms.txt', 'w') as f:
    f.write(out)
